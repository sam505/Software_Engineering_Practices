# %% [markdown]
# # Refactor: Wine Quality Analysis
# In this exercise, you'll refactor code that analyzes a wine quality dataset taken from the UCI Machine Learning Repository [here](https://archive.ics.uci.edu/ml/datasets/wine+quality). Each row contains data on a wine sample, including several physicochemical properties gathered from tests, as well as a quality rating evaluated by wine experts.
#
# The code in this notebook first renames the columns of the dataset and then calculates some statistics on how some features may be related to quality ratings. Can you refactor this code to make it more clean and modular?

# %%
import pandas as pd
df = pd.read_csv('winequality-red.csv', sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ### Renaming Columns
# You want to replace the spaces in the column labels with underscores to be able to reference columns with dot notation. Here's one way you could've done it.

# %%
new_df = df.rename(columns={'fixed acidity': 'fixed_acidity',
                             'volatile acidity': 'volatile_acidity',
                             'citric acid': 'citric_acid',
                             'residual sugar': 'residual_sugar',
                             'free sulfur dioxide': 'free_sulfur_dioxide',
                             'total sulfur dioxide': 'total_sulfur_dioxide'
                            })
new_df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# And here's a slightly better way you could do it. You can avoid making naming errors due to typos caused by manual typing. However, this looks a little repetitive. Can you make it better?

# %%
labels = list(df.columns)
for i in range(7):
    labels[i] = labels[i].replace(' ', '_')
df.columns = labels

df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ### Analyzing Features
# Now that your columns are ready, you want to see how different features of this dataset relate to the quality rating of the wine. A very simple way you could do this is by observing the mean quality rating for the top and bottom half of each feature. The code below does this for four features. It looks pretty repetitive right now. Can you make this more concise?
#
# You might challenge yourself to figure out how to make this code more efficient! But you don't need to worry too much about efficiency right now - we will cover that more in the next section.

# %%
def get_features(name, df, df_feature):
    median_feature = df_feature.median()
    for i, feature in enumerate(df_feature):
        if feature >= median_feature:
            df.loc[i, name] = 'high'
        else:
            df.loc[i, name] = 'low'
    df.groupby(name).quality.mean()

# %%
for feature in df.columns:
    get_features(feature, df, df[feature])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/generic.py in array_func(values)
#     339             try:
# --> 340                 result = self.grouper._cython_operation(
#     341                     "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     977         ngroups = self.ngroups
# --> 978         return cy_op.cython_operation(
#     979             values=values,
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     638
# --> 639         return self._cython_op_ndim_compat(
#     640             values,
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, **kwargs)
#     480             values2d = values[None, :]
# --> 481             res = self._call_cython_op(
#     482                 values2d,
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _call_cython_op(self, values, min_count, ngroups, comp_ids, mask, **kwargs)
#     540         out_shape = self._get_output_shape(ngroups, values)
# --> 541         func, values = self.get_cython_func_and_vals(values, is_numeric)
#     542         out_dtype = self.get_out_dtype(values.dtype)
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/ops.py in get_cython_func_and_vals(self, values, is_numeric)
#     203
# --> 204         func = self._get_cython_function(kind, how, values.dtype, is_numeric)
#     205
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _get_cython_function(cls, kind, how, dtype, is_numeric)
#     168                 # raise NotImplementedError here rather than TypeError later
# --> 169                 raise NotImplementedError(
#     170                     f"function is not implemented for this dtype: "
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1601         try:
# -> 1602             x = float(x)
#    1603         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1605             try:
# -> 1606                 x = complex(x)
#    1607             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_145898/33381469.py in <module>
#       1 for feature in df.columns:
# ----> 2     get_features(feature, df, df[feature])
#
# /tmp/ipykernel_145898/2535504002.py in get_features(name, df, df_feature)
#       6         else:
#       7             df.loc[i, name] = 'low'
# ----> 8     df.groupby(name).quality.mean()
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1663         numeric_only = self._resolve_numeric_only(numeric_only)
#    1664
# -> 1665         result = self._cython_agg_general(
#    1666             "mean",
#    1667             alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     350             return result
#     351
# --> 352         result = array_func(objvals)
#     353
#     354         ser = self.obj._constructor(
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/generic.py in array_func(values)
#     346                 # try to python agg
#     347                 # TODO: shouldn't min_count matter?
# --> 348                 result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#     349
#     350             return result
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, values, ndim, alt)
#    1374         #  should always be preserved by the implemented aggregations
#    1375         # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1376         res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1377
#    1378         if isinstance(values, Categorical):
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#    1026
#    1027         else:
# -> 1028             result = self._aggregate_series_fast(obj, func)
#    1029
#    1030         npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#    1051         ids = ids.take(indexer)
#    1052         sgrouper = libreduction.SeriesGrouper(obj, func, ids, ngroups)
# -> 1053         result, _ = sgrouper.get_result()
#    1054         return result
#    1055
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction._BaseGrouper._apply_to_group()
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1665         result = self._cython_agg_general(
#    1666             "mean",
# -> 1667             alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1668             numeric_only=numeric_only,
#    1669         )
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10367
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10369         return self._stat_function(
#   10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10371         )
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10352                 name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10353             )
# > 10354         return self._reduce(
#   10355             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10356         )
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     153                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154             else:
# --> 155                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     156
#     157             return result
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     408             mask = isna(values)
#     409
# --> 410         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     411
#     412         if datetimelike:
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     663
#     664     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 665     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     666
#     667     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~/PycharmProjects/Software_Engineering_Practices/venv/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1607             except ValueError as err:
#    1608                 # e.g. "foo"
# -> 1609                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1610     return x
#    1611
#
# TypeError: Could not convert ... to numeric

# %%
df.head(10)
# Out:
# 0        low
# 1        low
# 2        low
# 3       high
# 4        low
#         ...
# 1594     low
# 1595     low
# 1596     low
# 1597     low
# 1598    high
# Name: citric_acid, Length: 1599, dtype: object
